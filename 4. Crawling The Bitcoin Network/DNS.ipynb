# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # DNS Seeds

# %% [markdown]
# By this time you've probably hit this error:
#
# ![image](../images/empty-list.png)
#
# It would be much better if we could prime our crawler with more addresses. It would be especially good if they were addresses of "high quality" nodes that are always online and have juicy peer lists to share with us.
#
# This is exactly what DNS seeds are for. Prominent bitcoin core developers run DNS servers from domains they contol which resolve not to the address of a machine serving a website -- which is true of most domain names -- but to a list of addresses of high quality bitcoin full nodes.
#
# These domains are actually [hard-coded into Bitcoin Core](https://github.com/bitcoin/bitcoin/blob/v0.17.1/src/chainparams.cpp#L127)!
#
# Some of them run [this crawler / server written by Peter Wuille](https://github.com/sipa/bitcoin-seeder).
#
# Let's learn to query these DNS seeds:

# %% [markdown]
# In your terminal type:
#
# ```shell
# $ dig dnsseed.bitcoin.dashjr.org
# ```
#
# This will perform a DNS lookup. We are interest in the "answers" sections, which shows a number of DNS "A records" for the host name `dnsseed.bitcoin.dashjr.org`. These are IP addresses of Bitcoin nodes!
#
# ![image](../images/dig.png)
#
#
# How can we do this from Python?
#
# Python's built-in [`socket.getaddrinfo`](https://docs.python.org/3/library/socket.html#socket.getaddrinfo) function can accomplish this.

# %%
# Copied from Bitcoin Core's src/chainparams.cpp file

DNS_SEEDS = [
    'dnsseed.bitcoin.dashjr.org', 
    'dnsseed.bluematt.me',
    'seed.bitcoin.sipa.be', 
    'seed.bitcoinstats.com',
    'seed.bitcoin.jonasschnelli.ch',
    'seed.btc.petertodd.org',
    'seed.bitcoin.sprovoost.nl',
    'dnsseed.emzy.de',
]

# %%
import socket

# getaddrinfo translates hostname -> ip address ... but it's messy
addr_info = socket.getaddrinfo(DNS_SEEDS[0], 8333)
addr_info
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.250.184.57', 8333))]

# %%
# Third param can filter down IPv4 or IPv6

# IPv4 example
socket.getaddrinfo(DNS_SEEDS[0], 8333, socket.AF_INET)
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.250.184.57', 8333))]

# %%
# IPv6 example
socket.getaddrinfo(DNS_SEEDS[0], 8333, socket.AF_INET6)
# Out:
# [(<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:212.47.248.113', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:178.63.52.205', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:173.249.60.241', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:89.176.84.97', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:89.176.84.97', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:72.250.184.57', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:207.154.235.64', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:207.154.235.64', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:18.216.225.154', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:178.3.37.35', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:157.230.154.15', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:157.230.154.15', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:89.25.80.42', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:94.9.45.139', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:212.47.248.113', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:178.63.52.205', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:192.228.181.224', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:192.228.181.224', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:18.179.8.34', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:176.9.137.26', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:176.9.137.26', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:70.114.203.132', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:213.99.244.58', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:68.183.104.3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:68.183.104.3', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:54.213.3.147', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:54.218.204.31', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:115.91.72.154', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:115.91.72.154', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:80.218.224.51', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:80.56.3.23', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:37.120.171.27', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:37.120.171.27', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('::ffff:85.184.254.239', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:54.213.3.147', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:54.218.204.31', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:85.184.254.239', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:18.179.8.34', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:89.25.80.42', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:173.249.60.241', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:80.218.224.51', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:70.114.203.132', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:178.3.37.35', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:213.99.244.58', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:80.56.3.23', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:94.9.45.139', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:18.216.225.154', 8333, 0, 0)),
#  (<AddressFamily.AF_INET6: 30>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('::ffff:72.250.184.57', 8333, 0, 0))]

# %%
# 0 accepts both (what we want)
socket.getaddrinfo(DNS_SEEDS[0], 8333, 0)
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.250.184.57', 8333))]

# %%
# 4th paramter sets the socket type (TCP, UDP, or RAW)

socket.getaddrinfo(DNS_SEEDS[0], 8333, 0, socket.SOCK_STREAM)
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.203.132', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.63.52.205', 8333))]

# %%
# Question: how would you getch the addresses configured for UDP?

socket.getaddrinfo(DNS_SEEDS[0], 8333, socket.AF_INET, socket.SOCK_DGRAM)
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_DGRAM: 2>,
#   17,
#   '',
#   ('70.114.203.132', 8333))]

# %%
# We want to accept IPv4 & IPv6 (3rd param set to 0)
# But only TCP socket types (4th param set to socket.SOCK_STREAM)
addr_info = socket.getaddrinfo(DNS_SEEDS[0], 8333, 0, socket.SOCK_STREAM)
addr_info
# Out:
# [(<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('212.47.248.113', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('192.228.181.224', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('37.120.171.27', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.63.52.205', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('176.9.137.26', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('213.99.244.58', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('68.183.104.3', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.213.3.147', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('54.218.204.31', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('115.91.72.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.218.224.51', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('80.56.3.23', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('94.9.45.139', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('85.184.254.239', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('173.249.60.241', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.176.84.97', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('72.250.184.57', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('207.154.235.64', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.216.225.154', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('178.3.37.35', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('157.230.154.15', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('89.25.80.42', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('18.179.8.34', 8333)),
#  (<AddressFamily.AF_INET: 2>,
#   <SocketKind.SOCK_STREAM: 1>,
#   6,
#   '',
#   ('70.114.203.132', 8333))]

# %%
# addresses in the last entry
addrs = [ai[-1] for ai in addr_info]
addrs
# Out:
# [('212.47.248.113', 8333),
#  ('192.228.181.224', 8333),
#  ('37.120.171.27', 8333),
#  ('178.63.52.205', 8333),
#  ('176.9.137.26', 8333),
#  ('213.99.244.58', 8333),
#  ('68.183.104.3', 8333),
#  ('54.213.3.147', 8333),
#  ('54.218.204.31', 8333),
#  ('115.91.72.154', 8333),
#  ('80.218.224.51', 8333),
#  ('80.56.3.23', 8333),
#  ('94.9.45.139', 8333),
#  ('85.184.254.239', 8333),
#  ('173.249.60.241', 8333),
#  ('89.176.84.97', 8333),
#  ('72.250.184.57', 8333),
#  ('207.154.235.64', 8333),
#  ('18.216.225.154', 8333),
#  ('178.3.37.35', 8333),
#  ('157.230.154.15', 8333),
#  ('89.25.80.42', 8333),
#  ('18.179.8.34', 8333),
#  ('70.114.203.132', 8333)]

# %%
# addresses in the last entry
addrs = [ai[-1][:2] for ai in addr_info]
addrs
# Out:
# [('212.47.248.113', 8333),
#  ('192.228.181.224', 8333),
#  ('37.120.171.27', 8333),
#  ('178.63.52.205', 8333),
#  ('176.9.137.26', 8333),
#  ('213.99.244.58', 8333),
#  ('68.183.104.3', 8333),
#  ('54.213.3.147', 8333),
#  ('54.218.204.31', 8333),
#  ('115.91.72.154', 8333),
#  ('80.218.224.51', 8333),
#  ('80.56.3.23', 8333),
#  ('94.9.45.139', 8333),
#  ('85.184.254.239', 8333),
#  ('173.249.60.241', 8333),
#  ('89.176.84.97', 8333),
#  ('72.250.184.57', 8333),
#  ('207.154.235.64', 8333),
#  ('18.216.225.154', 8333),
#  ('178.3.37.35', 8333),
#  ('157.230.154.15', 8333),
#  ('89.25.80.42', 8333),
#  ('18.179.8.34', 8333),
#  ('70.114.203.132', 8333)]

# %%
from mycrawler import Node

# Turn them into Node instances
nodes = [Node(*addr) for addr in addrs]

nodes
# Out:
# [Node(('212.47.248.113', 8333)),
#  Node(('192.228.181.224', 8333)),
#  Node(('37.120.171.27', 8333)),
#  Node(('178.63.52.205', 8333)),
#  Node(('176.9.137.26', 8333)),
#  Node(('213.99.244.58', 8333)),
#  Node(('68.183.104.3', 8333)),
#  Node(('54.213.3.147', 8333)),
#  Node(('54.218.204.31', 8333)),
#  Node(('115.91.72.154', 8333)),
#  Node(('80.218.224.51', 8333)),
#  Node(('80.56.3.23', 8333)),
#  Node(('94.9.45.139', 8333)),
#  Node(('85.184.254.239', 8333)),
#  Node(('173.249.60.241', 8333)),
#  Node(('89.176.84.97', 8333)),
#  Node(('72.250.184.57', 8333)),
#  Node(('207.154.235.64', 8333)),
#  Node(('18.216.225.154', 8333)),
#  Node(('178.3.37.35', 8333)),
#  Node(('157.230.154.15', 8333)),
#  Node(('89.25.80.42', 8333)),
#  Node(('18.179.8.34', 8333)),
#  Node(('70.114.203.132', 8333))]

# %%
from mycrawler import Connection

# Can we connect?
conn = Connection(nodes[0]).open()
# Out:
# Connecting to 212.47.248.113
# Received a "version"
# Received a "verack"
# Received a "sendheaders"
# Received a "sendcmpct"
# Received a "sendcmpct"
# Received a "ping"
# Received a "addr"
# Received a "getheaders"
# Received a "feefilter"
# Received a "inv"
# Received a "inv"

# %%
def query_dns_seeds():
    nodes = []
    for seed in DNS_SEEDS:
        try:
            addr_info = socket.getaddrinfo(seed, 8333, 0, socket.SOCK_STREAM)
            addresses = [ai[-1][:2] for ai in addr_info]
            nodes.extend([Node(*addr) for addr in addresses])
        except OSError as e:
            print(f"DNS seed query failed: {str(e)}")
    return nodes

# %%
# BEHOLD THE GLORIOUS BITCOIN NODES!!!

for node in query_dns_seeds():
    print(node.ip)
# Out:
# 89.25.80.42
# 192.228.181.224
# 18.179.8.34
# 176.9.137.26
# 70.114.203.132
# 213.99.244.58
# 68.183.104.3
# 54.213.3.147
# 54.218.204.31
# 115.91.72.154
# 80.218.224.51
# 80.56.3.23
# 178.63.52.205
# 85.184.254.239
# 173.249.60.241
# 89.176.84.97
# 72.250.184.57
# 207.154.235.64
# 18.216.225.154
# 178.3.37.35
# 157.230.154.15
# 94.9.45.139
# 37.120.171.27
# 212.47.248.113
# 78.40.244.243
# 47.75.211.209
# 75.135.174.73
# 73.83.15.72
# 178.33.142.194
# 46.229.165.154
# 5.45.75.100
# 52.68.125.112
# 172.101.247.252
# 159.69.56.213
# 138.68.23.88
# 68.183.229.242
# 92.32.119.96
# 185.25.48.184
# 18.202.91.9
# 163.172.82.118
# 93.213.123.49
# 52.17.157.167
# 144.76.40.117
# 65.19.155.82
# 80.100.12.188
# 161.117.11.26
# 109.236.84.116
# 62.210.69.209
# 95.154.40.9
# 47.74.213.20
# 96.255.227.185
# 52.47.198.36
# 34.210.147.106
# 85.214.210.168
# 23.98.43.170
# 88.208.52.166
# 148.66.58.26
# 200.69.239.88
# 178.128.139.6
# 130.255.187.86
# 195.201.87.168
# 157.230.226.43
# 213.174.156.86
# 89.154.95.56
# 76.95.70.61
# 80.84.54.26
# 37.187.119.41
# 46.166.174.77
# 45.32.24.156
# 13.229.122.58
# 178.128.39.110
# 188.166.55.112
# 54.172.18.254
# 46.239.92.204
# 133.202.247.179
# 82.165.23.226
# 112.120.111.37
# 35.240.97.49
# 58.146.222.198
# 72.230.237.11
# 80.98.24.110
# 104.199.142.247
# 178.254.21.239
# 58.110.113.38
# 94.3.55.106
# 98.225.157.78
# 35.204.103.207
# 54.251.130.195
# 46.101.99.121
# 198.27.83.20
# 173.212.200.48
# 86.20.30.237
# 71.45.114.164
# 117.80.182.128
# 68.12.134.60
# 39.104.57.172
# 114.220.199.53
# 84.196.164.227
# 71.218.51.209
# 178.128.94.250
# 50.209.135.25
# 85.10.195.250
# 35.181.34.5
# 165.227.78.80
# 59.110.12.129
# 75.70.234.54
# 84.43.181.174
# 159.65.153.137
# 62.78.183.210
# 47.88.175.168
# 72.221.232.149
# 199.247.1.117
# 121.228.9.62
# 35.187.212.60
# 54.37.150.195
# 94.130.179.91
# 139.59.138.73
# 54.36.234.240
# 76.168.139.198
# 52.25.248.172
# 128.69.112.128
# 75.83.93.186
# 18.205.209.222
# 94.242.213.80
# 5.144.90.27
# 47.97.123.122
# 62.212.141.33
# 88.99.191.169
# 183.193.215.90
# 84.29.195.207
# 178.128.49.199
# 193.117.160.194
# 109.201.142.116
# 5.144.88.6
# 198.37.103.151
# 144.76.136.19
# 95.154.90.99
# 3.1.21.31
# 18.224.61.247
# 72.83.200.22
# 174.16.206.3
# 78.94.240.180
# 13.229.107.209
# 5.9.101.140
# 23.225.149.202
# 78.157.91.120
# 104.236.64.173
# 35.188.213.234
# 18.138.66.56
# 73.249.51.152
# 86.133.231.194
# 178.128.20.65
# 84.196.164.227
# 54.184.246.214
# 83.41.96.13
# 79.51.134.201
# 39.98.184.253
# 159.203.171.139
# 98.243.38.253
# 151.80.45.170
# 47.89.242.60
# 95.216.203.192
# 185.21.216.134
# 1.64.71.162
# 153.126.173.143
# 80.181.191.121
# 129.232.253.2
# 104.199.192.149
# 144.76.235.51
# 62.163.55.132
# 35.201.193.137
# 34.222.116.184
# 209.133.220.135
# 78.108.108.162
# 5.196.248.44
# 95.105.177.157

# %% [markdown]
# BTW -- we're already using `getaddrinfo` under the hood when we call `socket.create_connection` ...
